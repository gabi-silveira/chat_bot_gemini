# %%
# !pip install -q -U google-generativeai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.7/150.7 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.8/677.8 kB 7.6 MB/s eta 0:00:00

# %%
import google.generativeai as genai

GOOGLE_API_KEY="*"
genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if 'generationcontent' in m.supported_generation_methods:
    print(m.name)

# %%
generation_config = {
    "candidate_count": 1,
    "temperature": 0.5,
 }

# %%
safety_settings = {
    "HATE" : "BLOCK_NONE",
}

# %%
model = genai.GenerativeModel(model_name="gemini-1.0-pro",
                              generation_config = generation_config)

# %%
response = model.generate_content("vamor aprender conteudo sobre AI. me de sugestoes.")
print(response.text)
# Out:
# **Cursos Online:**
#
# * **Coursera:**
#     * Aprendizado de Máquina
#     * Inteligência Artificial
#     * Visão Computacional
# * **edX:**
#     * Ciência de Dados e Aprendizado de Máquina
#     * Inteligência Artificial: Fundamentos e Aplicações
#     * Robótica e Inteligência Artificial
# * **Udemy:**
#     * Curso Completo de Inteligência Artificial
#     * Aprendizado de Máquina e Inteligência Artificial para Iniciantes
#     * Inteligência Artificial Prática com Python
#
# **Livros:**
#
# * **Inteligência Artificial: Uma Abordagem Moderna** (Stuart Russell e Peter Norvig)
# * **Aprendizado de Máquina** (Tom Mitchell)
# * **Aprendizado Profundo** (Ian Goodfellow, Yoshua Bengio e Aaron Courville)
# * **Inteligência Artificial: Um Guia Moderno** (Melanie Mitchell)
# * **Inteligência Artificial para Todos** (Andrew Ng e Ernest Davis)
#
# **Artigos e Publicações:**
#
# * **MIT Technology Review:** https://www.technologyreview.com/artificial-intelligence/
# * **Wired:** https://www.wired.com/category/artificial-intelligence/
# * **Nature Machine Intelligence:** https://www.nature.com/nmachintell/
# * **IEEE Transactions on Artificial Intelligence:** https://ieeexplore.ieee.org/xpl/RecentIssue.jsp?punumber=4916130
# * **AI Magazine:** https://www.aaai.org/ojs/index.php/aimagazine
#
# **Conferências e Eventos:**
#
# * **Conferência Internacional Conjunta sobre Inteligência Artificial (IJCAI)**
# * **Conferência sobre Sistemas de Processamento de Informação Neural (NeurIPS)**
# * **Conferência Internacional sobre Aprendizado de Máquina (ICML)**
# * **Conferência Internacional sobre Visão Computacional (ICCV)**
# * **Conferência Internacional sobre Robótica e Automação (ICRA)**
#
# **Recursos Adicionais:**
#
# * **OpenAI Gym:** https://gym.openai.com/
# * **TensorFlow:** https://www.tensorflow.org/
# * **PyTorch:** https://pytorch.org/
# * **scikit-learn:** https://scikit-learn.org/stable/
# * **Comunidade de IA do Reddit:** https://www.reddit.com/r/artificial/

# %%
chat = model.start_chat(history=[])

# %%
prompt = input("fale aqui: ")

while prompt != "fim":
  response = chat.send_message(prompt)
  print("resposta: ", response.text, "\n" )
  prompt = input("fale aqui: ")
# Out:
# fale aqui: o que é um periferico
# resposta:  Um periférico é um dispositivo de hardware que se conecta a um computador para fornecer recursos adicionais ou permitir a interação com o usuário.
#
# **Tipos de periféricos:**
#
# * **Entrada:** Recebem informações do usuário, como teclado, mouse, scanner, microfone.
# * **Saída:** Exibem ou reproduzem informações do computador, como monitor, impressora, alto-falantes.
# * **Armazenamento:** Armazenam dados, como discos rígidos, unidades flash, CDs/DVDs.
# * **Comunicação:** Conectam o computador a redes ou outros dispositivos, como roteadores, modems, placas de rede.
# * **Outros:** Dispositivos especializados que fornecem funções específicas, como impressoras 3D, câmeras web, leitores de código de barras.
#
# **Características dos periféricos:**
#
# * **Conectividade:** Conectam-se ao computador por meio de interfaces como USB, Bluetooth, HDMI ou portas seriais.
# * **Propósito:** Cada periférico tem uma função específica, como inserir dados, exibir informações ou armazenar arquivos.
# * **Compatibilidade:** Devem ser compatíveis com o sistema operacional e o hardware do computador.
# * **Desempenho:** A velocidade, capacidade e qualidade de um periférico podem variar dependendo do modelo e do fabricante.
# * **Portabilidade:** Alguns periféricos são portáteis e podem ser facilmente transportados, enquanto outros são fixos e projetados para uso em um local específico.
#
# fale aqui: fim
